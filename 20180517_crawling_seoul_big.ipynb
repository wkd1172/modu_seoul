# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as pd
from itertools import count
from collections import OrderedDict

# %%
2page
 https://bigdata.seoul.go.kr/share/selectPageListShare.do?r_id=P410&cnrs_seq=&sch_task_cl_code=&sch_text=&currentPage=2

# %%
def crawling_machine(midclass,max_page=None):
    data = []
    if midclass == "resident":
        url = "https://bigdata.seoul.go.kr/share/selectPageListShare.do?r_id=P410"

        for pg in count(1):
            pamrams = {
                "currentPage" : pg
            }
            html = requests.get(url,params = params).text
            soup = BeautifulSoup(html,"html.parser")
            for tag in soup.select(".board_list tbody tr td"):
                data.append(tag.text)
                print(data)
            return data
        else:
            pages = page + 1
            for pg in range(1,pages):
                pamrams = {
                    "currentPage" : pg
                }
                html = requests.get(url,params = params).text
                soup = BeautifulSoup(html,"html.parser")
                for tag in soup.select(".board_list tbody tr td"):
                    data.append(tag.text)
                    #except
                    print(data)
            return data

# %%
def crawling_machine(midclass,max_page=None):
    data = []
    post_dic = OrderedDict()
    if midclass == "resident":
        url = "https://bigdata.seoul.go.kr/share/selectPageListShare.do"
        for pg in count(1):
            pamrams = {
                "currentPage" : pg,
                "r_id" : "P410"
            }
            html = requests.get(url,params = params).text
            soup = BeautifulSoup(html,"html.parser")
            print(params)
            for tag in soup.select(".board_list tbody tr td"):
                if tag.text in post_dic:
                    return post_dic
                else:
                    post_dic[tag.text] = tag.text
            if max_page and (pg >= max_page):
                break
                #data.append(tag.text)
                #print(data)
        return post_dic
    else:
        return post_dic

# %%
def crawling_machine(midclass,max_page=None):
    data = []
    if midclass == "resident":
        url = "https://bigdata.seoul.go.kr/share/selectPageListShare.do"
        if max_page == None:
            for page in range(1,19):
                params = {
                    "currentPage" : page,
                    "r_id" : "P410"
                }
                html = requests.get(url,params = params).text
                soup = BeautifulSoup(html, "html.parser")
                for tag in soup.select(".board_list tbody tr td"):
                    data.append(tag.text)
            return data
        else:
            for page in range(1,max_page + 1):
                params = {
                    "currentPage" : page,
                    "r_id" : "P410"
                }
                html = requests.get(url,params = params).text
                soup = BeautifulSoup(html, "html.parser")
                for tag in soup.select(".board_list tbody tr td"):
                    data.append(tag.text)
            return data

# %%
crawling_machine("resident")
# Out:
# ['178',
#  '산업경제',
#  '2017 서울시빅데이터캠퍼스 상시공모전',
#  '1',
#  '0',
#  '0',
#  '2018.02.20',
#  '177',
#  '보건/복지',
#  'R을 이용한 빅데이터 분석',
#  '1',
#  '0',
#  '0',
#  '2018.02.20',
#  '176',
#  '도시관리',
#  '날씨에 따른 유동인구 변화분석',
#  '1',
#  '0',
#  '0',
#  '2018.02.20',
#  '175',
#  '보건/복지',
#  '미세먼지 민감지역 평가모델 개발',
#  '1',
#  '0',
#  '0',
#  '2018.02.20',
#  '174',
#  '도시관리',
#  '광장 내 혼잡도 분석',
#  '1',
#  '0',
#  '0',
#  '2018.02.20',
#  '173',
#  '교통',
#  '도로 속도 둔화에 따른 대중교통 이용 추천 시스템',
#  '1',
#  '0',
#  '0',
#  '2018.02.20',
#  '172',
#  '산업경제',
#  '과점 기업의 시장 진입 의사결정 분석',
#  '1',
#  '0',
#  '0',
#  '2018.02.20',
#  '171',
#  '안전',
#  '재난 대피소 현황 및 추가 개선사항 분석',
#  '1',
#  '0',
#  '0',
#  '2018.02.20',
#  '170',
#  '보건/복지',
#  '서울시 보육시설 현황과 대책',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '169',
#  '환경',
#  '서울시 상권 변동과 확산 시계열 분석',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '168',
#  '교통',
#  '지역별 소득수준과 지하철 발달의 관계',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '167',
#  '교통',
#  '서울시 공공자전거 따릉이 에 관한 빅데이터 분석',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '166',
#  '문화관광',
#  '의료관광활성화를 위한 빅데이터 분석 보고서',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '165',
#  '보건/복지',
#  '노인복지시설 수요예측',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '164',
#  '산업경제',
#  '자영업 창업자를 위한 설계자료',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '163',
#  '교통',
#  '택시기사 쉼터 만들기',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '162',
#  '일반행정',
#  '화재 건수에 따른 소방 기계 교체 순서 추천',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '161',
#  '교통',
#  '지역별 소득수준과 지하철 발달의 관계',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '160',
#  '기타',
#  '상시 공모전을 위한 데이터 탐색',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '159',
#  '교통',
#  '서울시 음주운전 사고 분석',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '158',
#  '환경',
#  '서울시 상권 변동과 확산 시계열 분석',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '157',
#  '기타',
#  '맵기반 음식점 식품위생 정보 제공 어플',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '156',
#  '교통',
#  '서울시 공공자전거 따릉이 에 관한 빅데이터 분석',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '155',
#  '보건/복지',
#  '서울시 빅데이터 캠퍼스 상시공모전',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '154',
#  '보건/복지',
#  '서울시 보육시설 현황과 대책',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '153',
#  '교통',
#  '서울시 공공자전거 따릉이 에 관한 빅데이터 분석',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '152',
#  '문화관광',
#  '의료관광활성화를 위한 빅데이터 분석 보고서',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '151',
#  '도시관리',
#  '거주 공간 분석을 통한 대학생 및 사회 초년생 거주 환경 개선',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '150',
#  '기타',
#  '카드매출데이터 분석',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '149',
#  '교통',
#  '빅데이터 분석을 통한 대중교통 접근성 향상',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '148',
#  '교통',
#  '서울시 공공자전거 따릉이 에 관한 빅데이터 분석',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '147',
#  '교통',
#  '교통안전시설물',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '146',
#  '산업경제',
#  '과점 기업의 시장 진입 의사결정 분석',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '145',
#  '보건/복지',
#  '서울시 빅데이터 캠퍼스 상시공모전',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '144',
#  '교통',
#  '서울특별시 빅데이터 분석 공모전',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '143',
#  '보건/복지',
#  '청소년 콘돔 자판기 설치를 위한 최적위치 선정',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '142',
#  '교통',
#  '서울시 따릉이 자전거 대여 서비스를 활용한 자전거 도로 분석 및 활성화 방안',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '141',
#  '교통',
#  '서울시 따릉이 자전거 대여 서비스를 활용한 자전거 도로 분석 및 활성화 방안',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '140',
#  '기타',
#  '발달상권 분석',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '139',
#  '일반행정',
#  '유동인구에 따른 입지 매력도 변화 분석',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '138',
#  '교통',
#  '빅데이터 분석을 통한 대중교통 접근성 향상',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '137',
#  '문화관광',
#  '국가별 관광수요 분석',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '136',
#  '일반행정',
#  '유동인구에 따른 입지 매력도 변화 분석',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '135',
#  '교통',
#  '유동인구분석에 따른 교통노선 개선',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '134',
#  '도시관리',
#  '도시 젠트리피케이션의 시공간 특성 분석과 상업적 젠트리피케이션의 시공간 단계 모델링',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '133',
#  '기타',
#  '소매업 및 외식업 매출분석',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '132',
#  '도시관리',
#  '상업지 물리적 환경분석을 통한 야간환경 관리계획',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '131',
#  '교통',
#  '서울의 강설 시 도로혼잡지역 분석',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '130',
#  '도시관리',
#  '날씨에 따른 유동인구 변화분석',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '129',
#  '교통',
#  '대중교통 OD 분석',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '128',
#  '도시관리',
#  '광장 내 혼잡도 분석',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '127',
#  '도시관리',
#  '부문별 기후변화 영향 및 취약성 통합평가 모형 기반구축 및 활용기술 개발',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '126',
#  '산업경제',
#  '소매업 매출액에 미치는 시간적 공간적 영향요인 차이분석',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '125',
#  '기타',
#  '서울시 미사일 대피소 부족 현황 파악',
#  '1',
#  '0',
#  '0',
#  '2017.12.20',
#  '124',
#  '산업경제',
#  '상권분석 및 도시구조 파악',
#  '1',
#  '0',
#  '0',
#  '2017.12.20',
#  '123',
#  '도시관리',
#  '유동인구에 따른 입지 매력도 변화 분석',
#  '1',
#  '0',
#  '0',
#  '2017.12.20',
#  '122',
#  '환경',
#  "Park's school - air quality",
#  '1',
#  '0',
#  '0',
#  '2017.12.20',
#  '121',
#  '도시관리',
#  '상업지 물리적 환경분석을 통한 야간환경 관리계획',
#  '1',
#  '0',
#  '0',
#  '2017.12.06',
#  '120',
#  '기타',
#  '신용카드 매출 패턴 분석',
#  '1',
#  '0',
#  '0',
#  '2017.12.06',
#  '119',
#  '교육',
#  '홍익대학교 공간빅데이터 수업',
#  '1',
#  '0',
#  '0',
#  '2017.12.06',
#  '118',
#  '교육',
#  '홍익대학교 공간빅데이터 수업',
#  '1',
#  '0',
#  '0',
#  '2017.12.06',
#  '117',
#  '기타',
#  '유동 인구에 따른 상권 분석',
#  '1',
#  '0',
#  '0',
#  '2017.12.06',
#  '116',
#  '기타',
#  '유동 인구에 따른 상권 분석',
#  '1',
#  '0',
#  '0',
#  '2017.12.06',
#  '115',
#  '교육',
#  '홍익대학교 공간빅데이터 수업',
#  '1',
#  '0',
#  '0',
#  '2017.12.06',
#  '114',
#  '기타',
#  '촛불시민 빅데이터 관련 분석',
#  '1',
#  '0',
#  '0',
#  '2017.12.06',
#  '113',
#  '기타',
#  '촛불시민 빅데이터 관련 분석',
#  '1',
#  '0',
#  '0',
#  '2017.12.06',
#  '112',
#  '기타',
#  '20대 건강상태 분석 및 대학가 부동산 데이터 분석',
#  '1',
#  '0',
#  '0',
#  '2017.10.10',
#  '111',
#  '교통',
#  '지하철 심야 운행 최적화',
#  '1',
#  '0',
#  '0',
#  '2017.09.28',
#  '110',
#  '기타',
#  '서울시 거리별 유동인구 변화 조사',
#  '1',
#  '0',
#  '0',
#  '2017.09.28',
#  '109',
#  '교통',
#  'Deep Neural Network를 이용한 지하철 부정승차객 적발',
#  '1',
#  '0',
#  '0',
#  '2017.09.28',
#  '108',
#  '교통',
#  'Deep Neural Network를 이용한 지하철 부정승차객 적발',
#  '1',
#  '0',
#  '0',
#  '2017.09.28',
#  '107',
#  '교통',
#  '폭염 및 오존이 서울시 대중교통이용 패턴에 미치는 영향 분석',
#  '1',
#  '0',
#  '0',
#  '2017.09.28',
#  '106',
#  '산업경제',
#  '창업하기에 적절한 위치와 예상 매출을 알려주는창업 추천 시스템 개발',
#  '1',
#  '0',
#  '0',
#  '2017.09.28',
#  '105',
#  '도시관리',
#  '유형별 유동인구패턴을 활용한 업종 분류 및 매출 분석과 지역별 업종  포화 비교분석',
#  '1',
#  '0',
#  '0',
#  '2017.09.28',
#  '104',
#  '도시관리',
#  '날씨에 따른 유동인구 변화분석',
#  '1',
#  '0',
#  '0',
#  '2017.09.28',
#  '103',
#  '산업경제',
#  '상권분석 및 도시구조 파악',
#  '1',
#  '0',
#  '0',
#  '2017.09.28',
#  '102',
#  '산업경제',
#  '데이터 리포트 엔진을 활용한 상권분석 보고서 고도화',
#  '1',
#  '0',
#  '0',
#  '2017.08.17',
#  '101',
#  '산업경제',
#  '스마트 모빌리티를 이용한 상권분석',
#  '1',
#  '0',
#  '0',
#  '2017.08.17',
#  '100',
#  '기타',
#  '통신사 데이터를 활용한 길단위 유동인구 생성',
#  '1',
#  '0',
#  '0',
#  '2017.08.17',
#  '99',
#  '기타',
#  '서울시청식당 식수인원예측',
#  '1',
#  '0',
#  '0',
#  '2017.08.17',
#  '98',
#  '산업경제',
#  '소매업 매출액에 미치는 시간적 공간적 영향요인 차이분석',
#  '1',
#  '0',
#  '0',
#  '2017.08.17',
#  '97',
#  '도시관리',
#  '매출액 및 생존율 추정 모형을 통한 소상공인 맞춤형 정보 제고 방안 인공지능 기반으로',
#  '1',
#  '0',
#  '0',
#  '2017.08.17',
#  '96',
#  '산업경제',
#  '소상공인 지원을 위한 상권분석 빅데이터 경진대회',
#  '1',
#  '0',
#  '0',
#  '2017.08.17',
#  '95',
#  '기타',
#  '빅데이터 큐레이팅기반의 상권 영향력 서비스',
#  '1',
#  '0',
#  '0',
#  '2017.08.17',
#  '94',
#  '산업경제',
#  '소상공인_골목상권 활성화 지역의 건물 특성 탐구',
#  '1',
#  '0',
#  '0',
#  '2017.08.17',
#  '93',
#  '기타',
#  '소상공인 지원을 위한 상권분석 빅데이터 경진대회',
#  '1',
#  '0',
#  '0',
#  '2017.08.17',
#  '92',
#  '도시관리',
#  '서울특별시의 사전투표소 최적입지 분석',
#  '1',
#  '0',
#  '0',
#  '2017.08.17',
#  '91',
#  '산업경제',
#  '홍대앞 상권의 발달 양상 시각화',
#  '1',
#  '0',
#  '0',
#  '2017.08.17',
#  '90',
#  '도시관리',
#  '도시 역동성 판단',
#  '1',
#  '0',
#  '0',
#  '2017.08.17',
#  '89',
#  '산업경제',
#  '정부 3.0 빅데이터를 활용한 스토리텔링 기반의 연관모델링 다차원 상권 분석 개발',
#  '1',
#  '0',
#  '0',
#  '2017.08.17',
#  '88',
#  '산업경제',
#  '블록별 특성 분석을 통한 신규 개업 업종 및 블록 추천 모형',
#  '1',
#  '0',
#  '0',
#  '2017.08.17',
#  '87',
#  '교통',
#  'Deep Neural Network를 이용한 지하철 부정승차객 적발',
#  '1',
#  '0',
#  '0',
#  '2017.08.17',
#  '86',
#  '산업경제',
#  '소매업 매출액에 미치는 시간적 공간적 영향요인 차이분석',
#  '1',
#  '0',
#  '0',
#  '2017.08.17',
#  '85',
#  '기타',
#  '데이터 기반 예술 프로젝트 진행을 위한 데이터 현황 사전조사',
#  '1',
#  '0',
#  '0',
#  '2017.08.17',
#  '84',
#  '도시관리',
#  '홍익대학교 도시공학과 GIS와 공간분석 수업',
#  '1',
#  '0',
#  '0',
#  '2017.06.20',
#  '83',
#  '도시관리',
#  '홍익대학교 도시공학과 GIS와 공간분석 수업',
#  '1',
#  '0',
#  '0',
#  '2017.06.20',
#  '82',
#  '도시관리',
#  '홍익대학교 도시공학과 GIS와 공간분석 수업',
#  '1',
#  '0',
#  '0',
#  '2017.06.20',
#  '81',
#  '기타',
#  '데이터 기반 예술 프로젝트 진행을 위한 데이터 현황 사전조사',
#  '1',
#  '0',
#  '0',
#  '2017.06.20',
#  '80',
#  '기타',
#  '데이터 기반 예술 프로젝트 진행을 위한 데이터 현황 사전조사',
#  '1',
#  '0',
#  '0',
#  '2017.06.20',
#  '79',
#  '기타',
#  '데이터 기반 예술 프로젝트 진행을 위한 데이터 현황 사전조사',
#  '1',
#  '0',
#  '0',
#  '2017.06.20',
#  '78',
#  '도시관리',
#  '빅데이터 분석을 통한 젠트리피케이션 예측 변수 도출',
#  '1',
#  '0',
#  '0',
#  '2017.06.20',
#  '77',
#  '일반행정',
#  '서울시 빅데이터 현황 파악 및 분석사례 검토',
#  '1',
#  '0',
#  '0',
#  '2017.06.20',
#  '76',
#  '도시관리',
#  '홍익대학교 도시공학과 GIS와 공간분석 수업',
#  '1',
#  '0',
#  '0',
#  '2017.06.20',
#  '75',
#  '도시관리',
#  '홍익대학교 도시공학과 GIS와 공간분석 수업',
#  '1',
#  '0',
#  '0',
#  '2017.06.20',
#  '74',
#  '일반행정',
#  '국가지점번호 설치 위치 선정',
#  '1',
#  '0',
#  '0',
#  '2017.06.20',
#  '73',
#  '도시관리',
#  '홍익대학교 도시공학과 GIS와 공간분석 수업',
#  '1',
#  '0',
#  '0',
#  '2017.06.20',
#  '72',
#  '안전',
#  '은평구 관내 CCTV 설치포인트 도출',
#  '1',
#  '0',
#  '0',
#  '2017.06.20',
#  '71',
#  '기타',
#  'K-CB group no.8',
#  '1',
#  '0',
#  '0',
#  '2017.05.30',
#  '70',
#  '기타',
#  '제3의 장소에서의 인터넷 연결 방법에 따른 미디어 이용 시공간 분석',
#  '1',
#  '0',
#  '0',
#  '2017.05.30',
#  '69',
#  '환경',
#  '서울시 미세먼지 분석',
#  '1',
#  '0',
#  '0',
#  '2017.05.30',
#  '68',
#  '기타',
#  'K-CB group no.5',
#  '1',
#  '0',
#  '0',
#  '2017.05.30',
#  '67',
#  '도시관리',
#  '홍익대학교 도시공학과 GIS와 공간분석 수업',
#  '1',
#  '0',
#  '0',
#  '2017.05.30',
#  '66',
#  '산업경제',
#  '소비자 행동 론',
#  '1',
#  '0',
#  '0',
#  '2017.05.30',
#  '65',
#  '기타',
#  'K-CB group no.5',
#  '1',
#  '0',
#  '0',
#  '2017.05.30',
#  '64',
#  '교통',
#  '전동휠체어 사용자들을 위한 네비게이션.enable',
#  '1',
#  '0',
#  '0',
#  '2017.05.30',
#  '63',
#  '기타',
#  'K-CB group no.2',
#  '1',
#  '0',
#  '0',
#  '2017.05.30',
#  '62',
#  '기타',
#  'K-CB group no.1',
#  '1',
#  '1',
#  '0',
#  '2017.05.30',
#  '61',
#  '도시관리',
#  '홍익대학교 도시공학과 GIS와 공간분석 수업',
#  '1',
#  '0',
#  '0',
#  '2017.05.30',
#  '60',
#  '도시관리',
#  '홍익대학교 도시공학과 GIS와 공간분석 수업',
#  '1',
#  '0',
#  '0',
#  '2017.05.30',
#  '59',
#  '도시관리',
#  '도시 공간구조 분석 졸업논문 관련 빅데이터 조사',
#  '1',
#  '0',
#  '0',
#  '2017.05.30',
#  '58',
#  '도시관리',
#  '도시내부구조의 역동성파악',
#  '1',
#  '0',
#  '0',
#  '2017.05.25',
#  '57',
#  '도시관리',
#  '홍익대학교 도시공학과 GIS와 공간분석 수업',
#  '1',
#  '0',
#  '0',
#  '2017.05.10',
#  '56',
#  '도시관리',
#  '압구정동 개발 방향 설정',
#  '1',
#  '0',
#  '0',
#  '2017.05.10',
#  '55',
#  '교통',
#  '서울시 자전거 이용 특성 분석',
#  '1',
#  '0',
#  '0',
#  '2017.05.10',
#  '54',
#  '도시관리',
#  '홍익대학교 도시공학과 GIS와 공간분석 수업',
#  '1',
#  '0',
#  '0',
#  '2017.05.02',
#  '53',
#  '환경',
#  '서울시 미세먼지 분석',
#  '1',
#  '0',
#  '0',
#  '2017.05.02',
#  '52',
#  '산업경제',
#  '소매업 매출액에 미치는 시간적 공간적 영향요인 차이분석',
#  '1',
#  '0',
#  '0',
#  '2017.05.02',
#  '51',
#  '교통',
#  '자전거 사고 다발지점 분석',
#  '1',
#  '0',
#  '0',
#  '2017.05.02',
#  '50',
#  '교육',
#  '서울시 커피프렌차이즈의 입지 분석',
#  '1',
#  '0',
#  '0',
#  '2017.04.17',
#  '49',
#  '산업경제',
#  '서울연구원 연구과제진행',
#  '1',
#  '0',
#  '0',
#  '2017.04.17',
#  '48',
#  '보건/복지',
#  '장애인 셔틀버스를 활용한 장애인 의료접근성 향상을 위하 연구 : 장애인 복지카드 사용의 공간 분석을 기반으로',
#  '1',
#  '0',
#  '0',
#  '2017.03.03',
#  '47',
#  '환경',
#  '미세먼지 및 대기오염에 따른 공원 이용 감소 패턴',
#  '1',
#  '0',
#  '0',
#  '2017.03.02',
#  '46',
#  '기타',
#  '서울시 교회 분포와 행정동 특성간의 공간적 상관성 파악에 관련 연구',
#  '1',
#  '0',
#  '0',
#  '2017.03.02',
#  '45',
#  '도시관리',
#  '상업가로에서 노점상(거리가게)의 입지가 주변상권 및 지역에 미치는 영향',
#  '1',
#  '0',
#  '0',
#  '2017.02.21',
#  '44',
#  '도시관리',
#  '업종별 소매업 매출액의 결정요인에 관한 연구',
#  '1',
#  '0',
#  '0',
#  '2017.02.01',
#  '43',
#  '산업경제',
#  '서울시 상권 연관성 분석',
#  '1',
#  '0',
#  '0',
#  '2017.01.11',
#  '42',
#  '도시관리',
#  '상업가로에서 노점상(거리가게)의 입지가 주변상권 및 지역에 미치는 영향',
#  '1',
#  '0',
#  '0',
#  '2017.01.02',
#  '41',
#  '도시관리',
#  '도시 구조와 디자인이 비동력 통행(걷기 및 자전거 타기)에 미치는 영향',
#  '1',
#  '0',
#  '0',
#  '2017.01.02',
#  '40',
#  '산업경제',
#  '실시간 교통 흐름이 업종별 매출액에 미치는 영향 및 차이분석',
#  '1',
#  '0',
#  '0',
#  '2017.01.02',
#  '39',
#  '환경',
#  '기후변화 취약성 지도의 작성_폭염피해를 중심으로 ',
#  '1',
#  '0',
#  '0',
#  '2017.01.02',
#  '38',
#  '도시관리',
#  '유동인구조사',
#  '1',
#  '0',
#  '0',
#  '2017.01.02',
#  '37',
#  '환경',
#  '미세먼지 및 대기오염에 따른 공원 이용 감소 패턴',
#  '1',
#  '0',
#  '0',
#  '2017.01.02',
#  '36',
#  '환경',
#  '서울시 폭염취약성 연구',
#  '1',
#  '0',
#  '0',
#  ...]

# %%
else:
            pages = page + 1
            for pg in range(1,pages):
                pamrams = {
                    "currentPage" : pg
                }
                html = requests.get(url,params = params).text
                soup = BeautifulSoup(html,"html.parser")
                for tag in soup.select(".board_list tbody tr td"):
                    data.append(tag.text)
                    #except
                    print(data)
            return data
# Out:
#   File "<ipython-input-54-f5856a5bcbec>", line 1
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
url = "https://bigdata.seoul.go.kr/share/selectPageListShare.do?r_id=P410"
data = []
for pg in range(1,10):
    params = {
    "currentPage" : pg
    }
    html = requests.get(url,params = params).text
    soup = BeautifulSoup(html,"html.parser")
    for tag in soup.select(".board_list tbody tr td"):
        no = tag.text
        data.append(no)
        
        #break
    break
data
# Out:
# ['178',
#  '산업경제',
#  '2017 서울시빅데이터캠퍼스 상시공모전',
#  '1',
#  '0',
#  '0',
#  '2018.02.20',
#  '177',
#  '보건/복지',
#  'R을 이용한 빅데이터 분석',
#  '1',
#  '0',
#  '0',
#  '2018.02.20',
#  '176',
#  '도시관리',
#  '날씨에 따른 유동인구 변화분석',
#  '1',
#  '0',
#  '0',
#  '2018.02.20',
#  '175',
#  '보건/복지',
#  '미세먼지 민감지역 평가모델 개발',
#  '1',
#  '0',
#  '0',
#  '2018.02.20',
#  '174',
#  '도시관리',
#  '광장 내 혼잡도 분석',
#  '1',
#  '0',
#  '0',
#  '2018.02.20',
#  '173',
#  '교통',
#  '도로 속도 둔화에 따른 대중교통 이용 추천 시스템',
#  '1',
#  '0',
#  '0',
#  '2018.02.20',
#  '172',
#  '산업경제',
#  '과점 기업의 시장 진입 의사결정 분석',
#  '1',
#  '0',
#  '0',
#  '2018.02.20',
#  '171',
#  '안전',
#  '재난 대피소 현황 및 추가 개선사항 분석',
#  '1',
#  '0',
#  '0',
#  '2018.02.20',
#  '170',
#  '보건/복지',
#  '서울시 보육시설 현황과 대책',
#  '1',
#  '0',
#  '0',
#  '2018.01.24',
#  '169',
#  '환경',
#  '서울시 상권 변동과 확산 시계열 분석',
#  '1',
#  '0',
#  '0',
#  '2018.01.24']
